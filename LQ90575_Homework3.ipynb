# %%
# This is where I just test code

import importlib
import functions as functions
from functions import *
importlib.reload(functions)

EPSILON = 0.1



solution = sim_run(EPSILON)
# Plot graphs here
x = arange(1, len(solution[0]) + 1) # Needed for the x-axis
plt.title(f"epsilon = {EPSILON}", fontsize = 10)
plt.xlabel("Time (t)")
plt.xticks(arange(1, len(solution[0]), step = len(solution[0]) / 10))
# plt.yticks
plt.xlim(right = len(solution[0]))

# Plotting Average Observed Reward here
plt.ylabel("Average Observed Reward")
plt.plot(x, solution[0])

# Plotting Percentage of Optimal Action Selection
plt.ylabel("% of Optimal Action Selection")
plt.plot(x, solution[1])

# print(f"{solution[0][-1]}\t{solution[1][-1]}")

print("\n\nEXITED WITHOUT ERROR")
# Out:
# FINISHED SIM
#
#
# EXITED WITHOUT ERROR
